# %%
import requests
import json
import uuid

URL = "http://localhost:8000/predict_batch"

# Tạo batch comment mẫu để test
payload = {
    "batch": [
        {
            "id": str(uuid.uuid4()),
            "text": "mày đúng là đồ_ngu, không biết suy_nghĩ gì cả"
        },
        {
            "id": str(uuid.uuid4()),
            "text": "sản_phẩm này dùng khá tốt, mình thấy ổn"
        },
        {
            "id": str(uuid.uuid4()),
            "text": "bọn này toàn lừa_đảo, không nên tin"
        }
    ]
}

print("📤 Sending request...")
resp = requests.post(URL, json=payload, timeout=30)

print("Status code:", resp.status_code)

if resp.status_code == 200:
    data = resp.json()
    print("\n📥 API Response:")
    print(json.dumps(data, indent=2, ensure_ascii=False))
else:
    print("❌ Error response:")
    print(resp.text)
# Out:
# 📤 Sending request...
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Quyen\miniconda3\envs\kafka-stream\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\Quyen\miniconda3\envs\kafka-stream\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
import pymongo

# Kết nối vào MongoDB (Localhost vì chạy từ máy thật)
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Database và Collection
db = client["toxic_db"]
col = db["monitor_logs"]

# Đếm tổng số dòng
count = col.count_documents({})
print(f"🔹 Tổng số bản ghi trong 'monitor_logs': {count}")

# In ra 5 dòng mới nhất
print("\n🔹 5 Bản ghi mới nhất:")
cursor = col.find().sort("_id", -1).limit(5)
for doc in cursor:
    print(doc)
    print("-" * 50)
# Out:
# 🔹 Tổng số bản ghi trong 'monitor_logs': 13726
#
# 🔹 5 Bản ghi mới nhất:
# {'_id': ObjectId('697b0d56be199e373dd4edaf'), 'id': '6dee0223-ad64-44df-871d-2bdb77c7447f', 'cmt': 'NPC trong kinh thánh thuần phổi bạn và ngu ngốc @@ \nVừa ra bộ phim House of David kể về vua David của Israel xem cuốn lắm', 'Individual': 'Hate', 'Group': 'Normal', 'Societal': 'Normal', 'type_attack': ['Intelligence', 'Politics', 'Community'], 'is_hate': True, 'timestamp': datetime.datetime(2026, 1, 29, 7, 33, 42, 19000)}
# --------------------------------------------------
# ...
